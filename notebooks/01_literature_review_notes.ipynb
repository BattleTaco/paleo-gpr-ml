# %% [markdown]
# # 01 – Literature Review Notes
#
# Use this notebook to record and organise notes from papers surveyed for the project.
# Populate `docs/literature_matrix.md` with summaries as you go.

# %% [markdown]
# ## GPR & Subsurface Detection
#
# <!-- Add paper summaries here -->

# %% [markdown]
# ## ML for Geophysical Data
#
# <!-- Add paper summaries here -->

# %% [markdown]
# ## Paleontology & Fossil Prospecting
#
# <!-- Add paper summaries here -->
