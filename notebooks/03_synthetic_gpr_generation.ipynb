# %% [markdown]
# # 03 – Synthetic GPR Generation
#
# Notebook for generating synthetic GPR B-scans for use in model training and testing.
# See `configs/gpr_synthetic.yaml` for simulation parameters.

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

from src.config import CONFIGS_DIR, PROCESSED_DATA_DIR
from src.utils.io import load_yaml
from src.visualization.plot_gpr import plot_bscan

# %%
config = load_yaml(CONFIGS_DIR / 'gpr_synthetic.yaml')
print(config['synthetic'])

# %% [markdown]
# ## Generate a synthetic B-scan
#
# TODO: call gprMax or a custom FDTD wrapper to produce synthetic data.
