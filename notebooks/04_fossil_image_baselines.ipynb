# %% [markdown]
# # 04 – Fossil Image Baselines
#
# Establish baseline classification performance on fossil / bone image data.

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

from src.config import RAW_DATA_DIR, PROCESSED_DATA_DIR, CONFIGS_DIR
from src.utils.io import load_yaml
from src.data.preprocess_fossils import load_image, resize_images

# %%
config = load_yaml(CONFIGS_DIR / 'fossil_classifier.yaml')
print(config)

# %% [markdown]
# ## Load sample images
#
# TODO: replace paths below with actual dataset paths.

# %%
# img_paths = sorted((RAW_DATA_DIR / 'fossils').glob('*.jpg'))[:5]
# images = [load_image(p) for p in img_paths]
# resized = resize_images(images, size=tuple(config['data']['image_size']))
# fig, axes = plt.subplots(1, len(resized), figsize=(15, 4))
# for ax, img in zip(axes, resized):
#     ax.imshow(img)
#     ax.axis('off')
# plt.tight_layout()
# plt.show()
