# %% [markdown]
# # 02 – GPR Data Exploration
#
# Exploratory analysis of raw and preprocessed GPR B-scan data.

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

from src.config import RAW_DATA_DIR, PROCESSED_DATA_DIR
from src.visualization.plot_gpr import plot_bscan

# %% [markdown]
# ## Load a sample B-scan
#
# Replace the path below with your actual data file.

# %%
# bscan = np.load(RAW_DATA_DIR / 'sample_bscan.npy')
# plot_bscan(bscan, dt=0.2, dx=0.05)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Preprocessing pipeline

# %%
from src.data.preprocess_gpr import time_zero_correction, dewow, normalize

# bscan_proc = normalize(dewow(time_zero_correction(bscan)))
# plot_bscan(bscan_proc, dt=0.2, dx=0.05, title='Preprocessed B-scan')
# plt.show()
